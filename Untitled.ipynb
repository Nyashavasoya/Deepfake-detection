# %%
import os
import torch
import torchaudio
import numpy as np
import pandas as pd
from torch.utils.data import Dataset, DataLoader, random_split
from torchmetrics import AveragePrecision
from models.AASIST import Model

# Configurations
SAMPLE_RATE = 16000
BATCH_SIZE = 16
TRAIN_RATIO = 0.7
DEV_RATIO = 0.15
TEST_RATIO = 0.15

# Device setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"[INFO] Using device: {device}")

# Load metadata
def split_dataset(metadata_csv):
    print(f"[INFO] Loading and splitting metadata from {metadata_csv}")
    df = pd.read_csv(metadata_csv)
    print(f"[INFO] Total dataset size: {len(df)} samples")
    train_df, dev_df, test_df = np.split(df.sample(frac=1, random_state=42),
                                         [int(TRAIN_RATIO*len(df)), int((TRAIN_RATIO+DEV_RATIO)*len(df))])
    print(f"[INFO] Split sizes - Train: {len(train_df)}, Dev: {len(dev_df)}, Test: {len(test_df)}")
    return train_df, dev_df, test_df

class InTheWildDataset(Dataset):
    def __init__(self, data_df, audio_dir):
        self.data = data_df.reset_index(drop=True)
        self.audio_dir = audio_dir
        print(f"[INFO] Created dataset with {len(self.data)} samples from {audio_dir}")
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        row = self.data.iloc[idx]
        file_path = os.path.join(self.audio_dir, row['file'])
        label = 1 if row['label'] == 'spoof' else 0  # 1 for fake, 0 for real

        # Load audio
        try:
            waveform, sr = torchaudio.load(file_path)
            if idx % 100 == 0:  # Print details occasionally to avoid console spam
                print(f"[DEBUG] Loaded file {file_path} - Shape: {waveform.shape}, SR: {sr}, Label: {label}")
            
            if sr != SAMPLE_RATE:
                resampler = torchaudio.transforms.Resample(sr, SAMPLE_RATE)
                waveform = resampler(waveform)
                if idx % 100 == 0:
                    print(f"[DEBUG] Resampled to {SAMPLE_RATE}Hz - New shape: {waveform.shape}")

            # Convert to mono if stereo
            if waveform.shape[0] > 1:
                waveform = torch.mean(waveform, dim=0, keepdim=True)
                if idx % 100 == 0:
                    print(f"[DEBUG] Converted to mono - New shape: {waveform.shape}")
            
            # Ensure correct length (4 seconds for AASIST compatibility)
            target_length = SAMPLE_RATE * 4  # 64000 samples for 4 seconds at 16kHz
            if waveform.shape[1] > target_length:
                waveform = waveform[:, :target_length]
                if idx % 100 == 0:
                    print(f"[DEBUG] Trimmed to {target_length} samples - New shape: {waveform.shape}")
            else:
                pad_size = target_length - waveform.shape[1]
                waveform = torch.nn.functional.pad(waveform, (0, pad_size))
                if idx % 100 == 0:
                    print(f"[DEBUG] Padded with {pad_size} zeros - New shape: {waveform.shape}")

            # Return raw waveform with shape [time_steps] - the model will add channel dimension
            final_waveform = waveform.squeeze()
            final_label = torch.tensor(label, dtype=torch.long)
            
            if idx % 100 == 0:
                print(f"[DEBUG] Final waveform shape: {final_waveform.shape}, Label: {label}")
            
            return final_waveform, final_label
            
        except Exception as e:
            print(f"[ERROR] Error loading file {file_path}: {e}")
            # Return a dummy waveform as fallback
            dummy_waveform = torch.zeros(SAMPLE_RATE * 4)
            return dummy_waveform, torch.tensor(label, dtype=torch.long)

# Load AASIST model from checkpoint
def load_aasist_model(checkpoint_path):
    print(f"[INFO] Loading model from {checkpoint_path}")
    
    model_config = {
        "nb_samp": 64000,  # Updated to match our target length
        "first_conv": 128,
        "filts": [70, [1, 32], [32, 32], [32, 64], [64, 64]],
        "gat_dims": [64, 32],
        "pool_ratios": [0.5, 0.7, 0.5, 0.5],
        "temperatures": [2.0, 2.0, 100.0, 100.0]
    }
    
    print(f"[DEBUG] Model configuration: {model_config}")
    
    try:
        model = Model(model_config)
        print(f"[INFO] Model instance created")
        
        # Print model structure
        print(f"[DEBUG] Model architecture:\n{model}")
        
        # Count parameters
        total_params = sum(p.numel() for p in model.parameters())
        print(f"[INFO] Total model parameters: {total_params:,}")
        
        # Load weights
        print(f"[INFO] Loading weights from checkpoint...")
        model.load_state_dict(torch.load(checkpoint_path, map_location=device))
        print(f"[INFO] Weights loaded successfully")
        
        model.to(device)
        print(f"[INFO] Model moved to device: {device}")
        return model
    except Exception as e:
        print(f"[ERROR] Failed to load model: {e}")
        raise

# Training function
def train(model, train_loader, dev_loader, epochs=10, lr=1e-4):
    print(f"[INFO] Starting training for {epochs} epochs with learning rate {lr}")
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    for epoch in range(epochs):
        print(f"[INFO] Starting epoch {epoch+1}/{epochs}")
        model.train()
        print(f"[INFO] Model set to training mode")
        
        total_loss, correct, total = 0, 0, 0
        batch_count = 0
        
        for batch_idx, (waveform, label) in enumerate(train_loader):
            # Print batch info every few batches
            if batch_idx % 10 == 0:
                print(f"[INFO] Processing batch {batch_idx+1}/{len(train_loader)}")
                print(f"[DEBUG] Batch waveform shape: {waveform.shape}, Label shape: {label.shape}")
            
            # Move to device
            waveform = waveform.to(device)
            label = label.to(device)
            
            if batch_idx % 10 == 0:
                print(f"[DEBUG] Data moved to {device}")
            
            # Reset gradients
            optimizer.zero_grad()
            
            try:
                # Forward pass
                if batch_idx % 10 == 0:
                    print(f"[DEBUG] Running forward pass...")
                
                _, output = model(waveform)  # Model returns (last_hidden, output)
                
                if batch_idx % 10 == 0:
                    print(f"[DEBUG] Forward pass complete. Output shape: {output.shape}")
                    print(f"[DEBUG] Sample outputs: {output[0]}")
                
                # Calculate loss
                loss = criterion(output, label)
                if batch_idx % 10 == 0:
                    print(f"[DEBUG] Loss: {loss.item():.4f}")
                
                # Backward pass
                loss.backward()
                if batch_idx % 10 == 0:
                    print(f"[DEBUG] Backward pass complete")
                
                # Update weights
                optimizer.step()
                if batch_idx % 10 == 0:
                    print(f"[DEBUG] Weights updated")
                
                # Track metrics
                total_loss += loss.item()
                pred = output.argmax(dim=1)
                batch_correct = (pred == label).sum().item()
                correct += batch_correct
                total += label.size(0)
                batch_count += 1
                
                if batch_idx % 10 == 0:
                    batch_acc = batch_correct / label.size(0)
                    print(f"[DEBUG] Batch accuracy: {batch_acc:.4f} ({batch_correct}/{label.size(0)})")
                
            except Exception as e:
                print(f"[ERROR] Exception during training batch {batch_idx}: {e}")
                import traceback
                traceback.print_exc()
                continue
        
        # Calculate epoch metrics
        epoch_loss = total_loss / batch_count if batch_count > 0 else 0
        train_acc = correct / total if total > 0 else 0
        
        print(f"[INFO] Evaluating on dev set...")
        dev_acc = evaluate(model, dev_loader)
        
        print(f"[RESULT] Epoch {epoch+1}/{epochs}, Loss: {epoch_loss:.4f}, Train Accuracy: {train_acc:.4f}, Dev Accuracy: {dev_acc:.4f}")

def evaluate(model, dataloader):
    print(f"[INFO] Starting evaluation on {len(dataloader)} batches")
    model.eval()
    print(f"[INFO] Model set to evaluation mode")
    
    correct, total = 0, 0
    
    with torch.no_grad():
        for batch_idx, (waveform, label) in enumerate(dataloader):
            if batch_idx % 10 == 0:
                print(f"[INFO] Evaluating batch {batch_idx+1}/{len(dataloader)}")
                print(f"[DEBUG] Batch waveform shape: {waveform.shape}")
            
            waveform = waveform.to(device)
            label = label.to(device)
            
            try:
                _, output = model(waveform)  # Model returns (last_hidden, output)
                
                pred = output.argmax(dim=1)
                batch_correct = (pred == label).sum().item()
                correct += batch_correct
                total += label.size(0)
                
                if batch_idx % 10 == 0:
                    batch_acc = batch_correct / label.size(0)
                    print(f"[DEBUG] Batch accuracy: {batch_acc:.4f} ({batch_correct}/{label.size(0)})")
                
            except Exception as e:
                print(f"[ERROR] Exception during evaluation batch {batch_idx}: {e}")
                continue
    
    final_acc = correct / total if total > 0 else 0
    print(f"[RESULT] Evaluation complete. Accuracy: {final_acc:.4f} ({correct}/{total})")
    return final_acc

print("[INFO] Script starting...")


audio_dir = "release_in_the_wild"
print(f"[INFO] Processing data from directory: {audio_dir}")

train_df, dev_df, test_df = split_dataset("release_in_the_wild/meta.csv")

print("[INFO] Creating datasets...")
train_dataset = InTheWildDataset(train_df, audio_dir)
dev_dataset = InTheWildDataset(dev_df, audio_dir)
test_dataset = InTheWildDataset(test_df, audio_dir)

print("[INFO] Creating data loaders...")
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
dev_loader = DataLoader(dev_dataset, batch_size=BATCH_SIZE)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
print(f"[INFO] Created {len(train_loader)} training batches, {len(dev_loader)} dev batches, {len(test_loader)} test batches")

# Load model and train
print("[INFO] Loading model...")
model = load_aasist_model("models/AASIST.pth")

print("[INFO] Starting training process...")
train(model, train_loader, dev_loader, epochs=10, lr=1e-4)

# Evaluate on test set
print("[INFO] Final evaluation on test set...")
test_accuracy = evaluate(model, test_loader)
print(f"[RESULT] Final Test Accuracy: {test_accuracy:.4f}")
print("[INFO] Script completed successfully")
# Out:
# [INFO] Using device: cuda
# [INFO] Script starting...
# [INFO] Processing data from directory: release_in_the_wild
# [INFO] Loading and splitting metadata from release_in_the_wild/meta.csv
# [INFO] Total dataset size: 31779 samples
# [INFO] Split sizes - Train: 22245, Dev: 4767, Test: 4767
# [INFO] Creating datasets...
# [INFO] Created dataset with 22245 samples from release_in_the_wild
# [INFO] Created dataset with 4767 samples from release_in_the_wild
# [INFO] Created dataset with 4767 samples from release_in_the_wild
# [INFO] Creating data loaders...
# [INFO] Created 1391 training batches, 298 dev batches, 298 test batches
# [INFO] Loading model...
# [INFO] Loading model from models/weights/AASIST.pth
# [DEBUG] Model configuration: {'nb_samp': 64000, 'first_conv': 128, 'filts': [70, [1, 32], [32, 32], [32, 64], [64, 64]], 'gat_dims': [64, 32], 'pool_ratios': [0.5, 0.7, 0.5, 0.5], 'temperatures': [2.0, 2.0, 100.0, 100.0]}
# [INFO] Model instance created
# [DEBUG] Model architecture:
# Model(
#   (conv_time): CONV()
#   (first_bn): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.5, inplace=True)
#   (drop_way): Dropout(p=0.2, inplace=True)
#   (selu): SELU(inplace=True)
#   (encoder): Sequential(
#     (0): Sequential(
#       (0): Residual_block(
#         (conv1): Conv2d(1, 32, kernel_size=(2, 3), stride=(1, 1), padding=(1, 1))
#         (selu): SELU(inplace=True)
#         (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(32, 32, kernel_size=(2, 3), stride=(1, 1), padding=(0, 1))
#         (conv_downsample): Conv2d(1, 32, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1))
#         (mp): MaxPool2d(kernel_size=(1, 3), stride=(1, 3), padding=0, dilation=1, ceil_mode=False)
#       )
#     )
#     (1): Sequential(
#       (0): Residual_block(
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv2d(32, 32, kernel_size=(2, 3), stride=(1, 1), padding=(1, 1))
#         (selu): SELU(inplace=True)
#         (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(32, 32, kernel_size=(2, 3), stride=(1, 1), padding=(0, 1))
#         (mp): MaxPool2d(kernel_size=(1, 3), stride=(1, 3), padding=0, dilation=1, ceil_mode=False)
#       )
#     )
#     (2): Sequential(
#       (0): Residual_block(
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv2d(32, 64, kernel_size=(2, 3), stride=(1, 1), padding=(1, 1))
#         (selu): SELU(inplace=True)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(2, 3), stride=(1, 1), padding=(0, 1))
#         (conv_downsample): Conv2d(32, 64, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1))
#         (mp): MaxPool2d(kernel_size=(1, 3), stride=(1, 3), padding=0, dilation=1, ceil_mode=False)
#       )
#     )
#     (3): Sequential(
#       (0): Residual_block(
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv2d(64, 64, kernel_size=(2, 3), stride=(1, 1), padding=(1, 1))
#         (selu): SELU(inplace=True)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(2, 3), stride=(1, 1), padding=(0, 1))
#         (mp): MaxPool2d(kernel_size=(1, 3), stride=(1, 3), padding=0, dilation=1, ceil_mode=False)
#       )
#     )
#     (4): Sequential(
#       (0): Residual_block(
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv2d(64, 64, kernel_size=(2, 3), stride=(1, 1), padding=(1, 1))
#         (selu): SELU(inplace=True)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(2, 3), stride=(1, 1), padding=(0, 1))
#         (mp): MaxPool2d(kernel_size=(1, 3), stride=(1, 3), padding=0, dilation=1, ceil_mode=False)
#       )
#     )
#     (5): Sequential(
#       (0): Residual_block(
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv1): Conv2d(64, 64, kernel_size=(2, 3), stride=(1, 1), padding=(1, 1))
#         (selu): SELU(inplace=True)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(2, 3), stride=(1, 1), padding=(0, 1))
#         (mp): MaxPool2d(kernel_size=(1, 3), stride=(1, 3), padding=0, dilation=1, ceil_mode=False)
#       )
#     )
#   )
#   (GAT_layer_S): GraphAttentionLayer(
#     (att_proj): Linear(in_features=64, out_features=64, bias=True)
#     (proj_with_att): Linear(in_features=64, out_features=64, bias=True)
#     (proj_without_att): Linear(in_features=64, out_features=64, bias=True)
#     (bn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (input_drop): Dropout(p=0.2, inplace=False)
#     (act): SELU(inplace=True)
#   )
#   (GAT_layer_T): GraphAttentionLayer(
#     (att_proj): Linear(in_features=64, out_features=64, bias=True)
#     (proj_with_att): Linear(in_features=64, out_features=64, bias=True)
#     (proj_without_att): Linear(in_features=64, out_features=64, bias=True)
#     (bn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (input_drop): Dropout(p=0.2, inplace=False)
#     (act): SELU(inplace=True)
#   )
#   (HtrgGAT_layer_ST11): HtrgGraphAttentionLayer(
#     (proj_type1): Linear(in_features=64, out_features=64, bias=True)
#     (proj_type2): Linear(in_features=64, out_features=64, bias=True)
#     (att_proj): Linear(in_features=64, out_features=32, bias=True)
#     (att_projM): Linear(in_features=64, out_features=32, bias=True)
#     (proj_with_att): Linear(in_features=64, out_features=32, bias=True)
#     (proj_without_att): Linear(in_features=64, out_features=32, bias=True)
#     (proj_with_attM): Linear(in_features=64, out_features=32, bias=True)
#     (proj_without_attM): Linear(in_features=64, out_features=32, bias=True)
#     (bn): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (input_drop): Dropout(p=0.2, inplace=False)
#     (act): SELU(inplace=True)
#   )
#   (HtrgGAT_layer_ST12): HtrgGraphAttentionLayer(
#     (proj_type1): Linear(in_features=32, out_features=32, bias=True)
#     (proj_type2): Linear(in_features=32, out_features=32, bias=True)
#     (att_proj): Linear(in_features=32, out_features=32, bias=True)
#     (att_projM): Linear(in_features=32, out_features=32, bias=True)
#     (proj_with_att): Linear(in_features=32, out_features=32, bias=True)
#     (proj_without_att): Linear(in_features=32, out_features=32, bias=True)
#     (proj_with_attM): Linear(in_features=32, out_features=32, bias=True)
#     (proj_without_attM): Linear(in_features=32, out_features=32, bias=True)
#     (bn): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (input_drop): Dropout(p=0.2, inplace=False)
#     (act): SELU(inplace=True)
#   )
#   (HtrgGAT_layer_ST21): HtrgGraphAttentionLayer(
#     (proj_type1): Linear(in_features=64, out_features=64, bias=True)
#     (proj_type2): Linear(in_features=64, out_features=64, bias=True)
#     (att_proj): Linear(in_features=64, out_features=32, bias=True)
#     (att_projM): Linear(in_features=64, out_features=32, bias=True)
#     (proj_with_att): Linear(in_features=64, out_features=32, bias=True)
#     (proj_without_att): Linear(in_features=64, out_features=32, bias=True)
#     (proj_with_attM): Linear(in_features=64, out_features=32, bias=True)
#     (proj_without_attM): Linear(in_features=64, out_features=32, bias=True)
#     (bn): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (input_drop): Dropout(p=0.2, inplace=False)
#     (act): SELU(inplace=True)
#   )
#   (HtrgGAT_layer_ST22): HtrgGraphAttentionLayer(
#     (proj_type1): Linear(in_features=32, out_features=32, bias=True)
#     (proj_type2): Linear(in_features=32, out_features=32, bias=True)
#     (att_proj): Linear(in_features=32, out_features=32, bias=True)
#     (att_projM): Linear(in_features=32, out_features=32, bias=True)
#     (proj_with_att): Linear(in_features=32, out_features=32, bias=True)
#     (proj_without_att): Linear(in_features=32, out_features=32, bias=True)
#     (proj_with_attM): Linear(in_features=32, out_features=32, bias=True)
#     (proj_without_attM): Linear(in_features=32, out_features=32, bias=True)
#     (bn): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (input_drop): Dropout(p=0.2, inplace=False)
#     (act): SELU(inplace=True)
#   )
#   (pool_S): GraphPool(
#     (sigmoid): Sigmoid()
#     (proj): Linear(in_features=64, out_features=1, bias=True)
#     (drop): Dropout(p=0.3, inplace=False)
#   )
#   (pool_T): GraphPool(
#     (sigmoid): Sigmoid()
#     (proj): Linear(in_features=64, out_features=1, bias=True)
#     (drop): Dropout(p=0.3, inplace=False)
#   )
#   (pool_hS1): GraphPool(
#     (sigmoid): Sigmoid()
#     (proj): Linear(in_features=32, out_features=1, bias=True)
#     (drop): Dropout(p=0.3, inplace=False)
#   )
#   (pool_hT1): GraphPool(
#     (sigmoid): Sigmoid()
#     (proj): Linear(in_features=32, out_features=1, bias=True)
#     (drop): Dropout(p=0.3, inplace=False)
#   )
#   (pool_hS2): GraphPool(
#     (sigmoid): Sigmoid()
#     (proj): Linear(in_features=32, out_features=1, bias=True)
#     (drop): Dropout(p=0.3, inplace=False)
#   )
#   (pool_hT2): GraphPool(
#     (sigmoid): Sigmoid()
#     (proj): Linear(in_features=32, out_features=1, bias=True)
#     (drop): Dropout(p=0.3, inplace=False)
#   )
#   (out_layer): Linear(in_features=160, out_features=2, bias=True)
# )
# [INFO] Total model parameters: 297,866
# [INFO] Loading weights from checkpoint...
# [INFO] Weights loaded successfully
# [INFO] Model moved to device: cuda
# [INFO] Starting training process...
# [INFO] Starting training for 10 epochs with learning rate 0.0001
# [INFO] Starting epoch 1/10
# [INFO] Model set to training mode
# [DEBUG] Loaded file release_in_the_wild/24337.wav - Shape: torch.Size([1, 27057]), SR: 16000, Label: 1
# [DEBUG] Padded with 36943 zeros - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 1
# [INFO] Processing batch 1/1391
# [DEBUG] Batch waveform shape: torch.Size([16, 64000]), Label shape: torch.Size([16])
# [DEBUG] Data moved to cuda
# [DEBUG] Running forward pass...
# [DEBUG] Forward pass complete. Output shape: torch.Size([16, 2])
# [DEBUG] Sample outputs: tensor([  8.8513, -10.2608], device='cuda:0', grad_fn=<SelectBackward0>)
# [DEBUG] Loss: 5.0955
# [DEBUG] Backward pass complete
# [DEBUG] Weights updated
# [DEBUG] Batch accuracy: 0.6250 (10/16)
# [DEBUG] Loaded file release_in_the_wild/4087.wav - Shape: torch.Size([1, 14208]), SR: 16000, Label: 0
# [DEBUG] Padded with 49792 zeros - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 0
# [INFO] Processing batch 11/1391
# [DEBUG] Batch waveform shape: torch.Size([16, 64000]), Label shape: torch.Size([16])
# [DEBUG] Data moved to cuda
# [DEBUG] Running forward pass...
# [DEBUG] Forward pass complete. Output shape: torch.Size([16, 2])
# [DEBUG] Sample outputs: tensor([ 6.8678, -7.6692], device='cuda:0', grad_fn=<SelectBackward0>)
# [DEBUG] Loss: 6.3398
# [DEBUG] Backward pass complete
# [DEBUG] Weights updated
# [DEBUG] Batch accuracy: 0.3125 (5/16)
# [DEBUG] Loaded file release_in_the_wild/14966.wav - Shape: torch.Size([1, 99809]), SR: 16000, Label: 0
# [DEBUG] Trimmed to 64000 samples - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 0
# [INFO] Processing batch 21/1391
# [DEBUG] Batch waveform shape: torch.Size([16, 64000]), Label shape: torch.Size([16])
# [DEBUG] Data moved to cuda
# [DEBUG] Running forward pass...
# [DEBUG] Forward pass complete. Output shape: torch.Size([16, 2])
# [DEBUG] Sample outputs: tensor([ 6.1114, -9.2338], device='cuda:0', grad_fn=<SelectBackward0>)
# [DEBUG] Loss: 3.9725
# [DEBUG] Backward pass complete
# [DEBUG] Weights updated
# [DEBUG] Batch accuracy: 0.4375 (7/16)
# [DEBUG] Loaded file release_in_the_wild/3980.wav - Shape: torch.Size([1, 77729]), SR: 16000, Label: 0
# [DEBUG] Trimmed to 64000 samples - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 0
# [DEBUG] Loaded file release_in_the_wild/20994.wav - Shape: torch.Size([1, 65265]), SR: 16000, Label: 0
# [DEBUG] Trimmed to 64000 samples - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 0
# [INFO] Processing batch 31/1391
# [DEBUG] Batch waveform shape: torch.Size([16, 64000]), Label shape: torch.Size([16])
# [DEBUG] Data moved to cuda
# [DEBUG] Running forward pass...
# [DEBUG] Forward pass complete. Output shape: torch.Size([16, 2])
# [DEBUG] Sample outputs: tensor([ 2.2104, -2.5653], device='cuda:0', grad_fn=<SelectBackward0>)
# [DEBUG] Loss: 1.1393
# [DEBUG] Backward pass complete
# [DEBUG] Weights updated
# [DEBUG] Batch accuracy: 0.6250 (10/16)
# [DEBUG] Loaded file release_in_the_wild/5087.wav - Shape: torch.Size([1, 49952]), SR: 16000, Label: 0
# [DEBUG] Padded with 14048 zeros - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 0
# [INFO] Processing batch 41/1391
# [DEBUG] Batch waveform shape: torch.Size([16, 64000]), Label shape: torch.Size([16])
# [DEBUG] Data moved to cuda
# [DEBUG] Running forward pass...
# [DEBUG] Forward pass complete. Output shape: torch.Size([16, 2])
# [DEBUG] Sample outputs: tensor([-1.9768,  0.7228], device='cuda:0', grad_fn=<SelectBackward0>)
# [DEBUG] Loss: 4.5846
# [DEBUG] Backward pass complete
# [DEBUG] Weights updated
# [DEBUG] Batch accuracy: 0.5000 (8/16)
# [INFO] Processing batch 51/1391
# [DEBUG] Batch waveform shape: torch.Size([16, 64000]), Label shape: torch.Size([16])
# [DEBUG] Data moved to cuda
# [DEBUG] Running forward pass...
# [DEBUG] Forward pass complete. Output shape: torch.Size([16, 2])
# [DEBUG] Sample outputs: tensor([-1.1054, -2.0831], device='cuda:0', grad_fn=<SelectBackward0>)
# [DEBUG] Loss: 2.4296
# [DEBUG] Backward pass complete
# [DEBUG] Weights updated
# [DEBUG] Batch accuracy: 0.4375 (7/16)
# [DEBUG] Loaded file release_in_the_wild/11947.wav - Shape: torch.Size([1, 40144]), SR: 16000, Label: 0
# [DEBUG] Padded with 23856 zeros - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 0
# [INFO] Processing batch 61/1391
# [DEBUG] Batch waveform shape: torch.Size([16, 64000]), Label shape: torch.Size([16])
# [DEBUG] Data moved to cuda
# [DEBUG] Running forward pass...
# [DEBUG] Forward pass complete. Output shape: torch.Size([16, 2])
# [DEBUG] Sample outputs: tensor([ 0.5347, -3.0971], device='cuda:0', grad_fn=<SelectBackward0>)
# [DEBUG] Loss: 0.4794
# [DEBUG] Backward pass complete
# [DEBUG] Weights updated
# [DEBUG] Batch accuracy: 0.8125 (13/16)
# [DEBUG] Loaded file release_in_the_wild/24895.wav - Shape: torch.Size([1, 102816]), SR: 16000, Label: 1
# [DEBUG] Trimmed to 64000 samples - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 1
# [DEBUG] Loaded file release_in_the_wild/28255.wav - Shape: torch.Size([1, 54160]), SR: 16000, Label: 0
# [DEBUG] Padded with 9840 zeros - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 0
# [INFO] Processing batch 71/1391
# [DEBUG] Batch waveform shape: torch.Size([16, 64000]), Label shape: torch.Size([16])
# [DEBUG] Data moved to cuda
# [DEBUG] Running forward pass...
# [DEBUG] Forward pass complete. Output shape: torch.Size([16, 2])
# [DEBUG] Sample outputs: tensor([-1.8663,  0.8645], device='cuda:0', grad_fn=<SelectBackward0>)
# [DEBUG] Loss: 0.3040
# [DEBUG] Backward pass complete
# [DEBUG] Weights updated
# [DEBUG] Batch accuracy: 0.8750 (14/16)
# [DEBUG] Loaded file release_in_the_wild/8817.wav - Shape: torch.Size([1, 24273]), SR: 16000, Label: 1
# [DEBUG] Padded with 39727 zeros - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 1
# [INFO] Processing batch 81/1391
# [DEBUG] Batch waveform shape: torch.Size([16, 64000]), Label shape: torch.Size([16])
# [DEBUG] Data moved to cuda
# [DEBUG] Running forward pass...
# [DEBUG] Forward pass complete. Output shape: torch.Size([16, 2])
# [DEBUG] Sample outputs: tensor([ 0.0299, -0.7382], device='cuda:0', grad_fn=<SelectBackward0>)
# [DEBUG] Loss: 0.5999
# [DEBUG] Backward pass complete
# [DEBUG] Weights updated
# [DEBUG] Batch accuracy: 0.6875 (11/16)
# [INFO] Processing batch 91/1391
# [DEBUG] Batch waveform shape: torch.Size([16, 64000]), Label shape: torch.Size([16])
# [DEBUG] Data moved to cuda
# [DEBUG] Running forward pass...
# [DEBUG] Forward pass complete. Output shape: torch.Size([16, 2])
# [DEBUG] Sample outputs: tensor([ 3.1580, -4.6397], device='cuda:0', grad_fn=<SelectBackward0>)
# [DEBUG] Loss: 0.1134
# [DEBUG] Backward pass complete
# [DEBUG] Weights updated
# [DEBUG] Batch accuracy: 0.8750 (14/16)
# [DEBUG] Loaded file release_in_the_wild/3299.wav - Shape: torch.Size([1, 53953]), SR: 16000, Label: 0
# [DEBUG] Padded with 10047 zeros - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 0
# [INFO] Processing batch 101/1391
# [DEBUG] Batch waveform shape: torch.Size([16, 64000]), Label shape: torch.Size([16])
# [DEBUG] Data moved to cuda
# [DEBUG] Running forward pass...
# [DEBUG] Forward pass complete. Output shape: torch.Size([16, 2])
# [DEBUG] Sample outputs: tensor([-0.0092, -0.4390], device='cuda:0', grad_fn=<SelectBackward0>)
# [DEBUG] Loss: 0.8030
# [DEBUG] Backward pass complete
# [DEBUG] Weights updated
# [DEBUG] Batch accuracy: 0.8750 (14/16)
# [INFO] Processing batch 111/1391
# [DEBUG] Batch waveform shape: torch.Size([16, 64000]), Label shape: torch.Size([16])
# [DEBUG] Data moved to cuda
# [DEBUG] Running forward pass...
# [DEBUG] Forward pass complete. Output shape: torch.Size([16, 2])
# [DEBUG] Sample outputs: tensor([-2.3582,  3.2711], device='cuda:0', grad_fn=<SelectBackward0>)
# [DEBUG] Loss: 0.6590
# [DEBUG] Backward pass complete
# [DEBUG] Weights updated
# [DEBUG] Batch accuracy: 0.8125 (13/16)
# [DEBUG] Loaded file release_in_the_wild/30987.wav - Shape: torch.Size([1, 48432]), SR: 16000, Label: 1
# [DEBUG] Padded with 15568 zeros - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 1
# [DEBUG] Loaded file release_in_the_wild/16793.wav - Shape: torch.Size([1, 173616]), SR: 16000, Label: 1
# [DEBUG] Trimmed to 64000 samples - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 1
# [DEBUG] Loaded file release_in_the_wild/25278.wav - Shape: torch.Size([1, 54321]), SR: 16000, Label: 0
# [DEBUG] Padded with 9679 zeros - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 0
# [DEBUG] Loaded file release_in_the_wild/1209.wav - Shape: torch.Size([1, 203057]), SR: 16000, Label: 0
# [DEBUG] Trimmed to 64000 samples - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 0
# [INFO] Processing batch 121/1391
# [DEBUG] Batch waveform shape: torch.Size([16, 64000]), Label shape: torch.Size([16])
# [DEBUG] Data moved to cuda
# [DEBUG] Running forward pass...
# [DEBUG] Forward pass complete. Output shape: torch.Size([16, 2])
# [DEBUG] Sample outputs: tensor([ 3.3860, -4.5042], device='cuda:0', grad_fn=<SelectBackward0>)
# [DEBUG] Loss: 0.4074
# [DEBUG] Backward pass complete
# [DEBUG] Weights updated
# [DEBUG] Batch accuracy: 0.8125 (13/16)
# [DEBUG] Loaded file release_in_the_wild/23212.wav - Shape: torch.Size([1, 65569]), SR: 16000, Label: 1
# [DEBUG] Trimmed to 64000 samples - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 1
# [INFO]
zeros - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 0
# [INFO] Processing batch 411/1391
# [DEBUG] Batch waveform shape: torch.Size([16, 64000]), Label shape: torch.Size([16])
# [DEBUG] Data moved to cuda
# [DEBUG] Running forward pass...
# [DEBUG] Forward pass complete. Output shape: torch.Size([16, 2])
# [DEBUG] Sample outputs: tensor([ 5.4191, -3.7667], device='cuda:0', grad_fn=<SelectBackward0>)
# [DEBUG] Loss: 0.4595
# [DEBUG] Backward pass complete
# [DEBUG] Weights updated
# [DEBUG] Batch accuracy: 0.8125 (13/16)
# [DEBUG] Loaded file release_in_the_wild/4242.wav - Shape: torch.Size([1, 57681]), SR: 16000, Label: 0
# [DEBUG] Padded with 6319 zeros - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 0
# [INFO] Processing batch 421/1391
# [DEBUG] Batch waveform shape: torch.Size([16, 64000]), Label shape: torch.Size([16])
# [DEBUG] Data moved to cuda
# [DEBUG] Running forward pass...
# [DEBUG] Forward pass complete. Output shape: torch.Size([16, 2])
# [DEBUG] Sample outputs: tensor([ 4.9992, -7.3674], device='cuda:0', grad_fn=<SelectBackward0>)
# [DEBUG] Loss: 0.1447
# [DEBUG] Backward pass complete
# [DEBUG] Weights updated
# [DEBUG] Batch accuracy: 0.9375 (15/16)
# [INFO] Processing batch 431/1391
# [DEBUG] Batch waveform shape: torch.Size([16, 64000]), Label shape: torch.Size([16])
# [DEBUG] Data moved to cuda
# [DEBUG] Running forward pass...
# [DEBUG] Forward pass complete. Output shape: torch.Size([16, 2])
# [DEBUG] Sample outputs: tensor([-2.1525,  0.7886], device='cuda:0', grad_fn=<SelectBackward0>)
# [DEBUG] Loss: 0.0444
# [DEBUG] Backward pass complete
# [DEBUG] Weights updated
# [DEBUG] Batch accuracy: 1.0000 (16/16)
# [DEBUG] Loaded file release_in_the_wild/1719.wav - Shape: torch.Size([1, 25889]), SR: 16000, Label: 1
# [DEBUG] Padded with 38111 zeros - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 1
# [DEBUG] Loaded file release_in_the_wild/23577.wav - Shape: torch.Size([1, 44769]), SR: 16000, Label: 1
# [DEBUG] Padded with 19231 zeros - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 1
# [INFO] Processing batch 441/1391
# [DEBUG] Batch waveform shape: torch.Size([16, 64000]), Label shape: torch.Size([16])
# [DEBUG] Data moved to cuda
# [DEBUG] Running forward pass...
# [DEBUG] Forward pass complete. Output shape: torch.Size([16, 2])
# [DEBUG] Sample outputs: tensor([ 4.2474, -4.4177], device='cuda:0', grad_fn=<SelectBackward0>)
# [DEBUG] Loss: 0.7676
# [DEBUG] Backward pass complete
# [DEBUG] Weights updated
# [DEBUG] Batch accuracy: 0.7500 (12/16)
# [DEBUG] Loaded file release_in_the_wild/766.wav - Shape: torch.Size([1, 54705]), SR: 16000, Label: 0
# [DEBUG] Padded with 9295 zeros - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 0
# [DEBUG] Loaded file release_in_the_wild/18788.wav - Shape: torch.Size([1, 26432]), SR: 16000, Label: 0
# [DEBUG] Padded with 37568 zeros - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 0
# [DEBUG] Loaded file release_in_the_wild/16911.wav - Shape: torch.Size([1, 43248]), SR: 16000, Label: 0
# [DEBUG] Padded with 20752 zeros - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 0
# [INFO] Processing batch 451/1391
# [DEBUG] Batch waveform shape: torch.Size([16, 64000]), Label shape: torch.Size([16])
# [DEBUG] Data moved to cuda
# [DEBUG] Running forward pass...
# [DEBUG] Forward pass complete. Output shape: torch.Size([16, 2])
# [DEBUG] Sample outputs: tensor([ 4.1193, -4.6010], device='cuda:0', grad_fn=<SelectBackward0>)
# [DEBUG] Loss: 0.1255
# [DEBUG] Backward pass complete
# [DEBUG] Weights updated
# [DEBUG] Batch accuracy: 0.9375 (15/16)
# [DEBUG] Loaded file release_in_the_wild/30596.wav - Shape: torch.Size([1, 14001]), SR: 16000, Label: 1
# [DEBUG] Padded with 49999 zeros - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 1
# [DEBUG] Loaded file release_in_the_wild/9500.wav - Shape: torch.Size([1, 45249]), SR: 16000, Label: 0
# [DEBUG] Padded with 18751 zeros - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 0
# [INFO] Processing batch 461/1391
# [DEBUG] Batch waveform shape: torch.Size([16, 64000]), Label shape: torch.Size([16])
# [DEBUG] Data moved to cuda
# [DEBUG] Running forward pass...
# [DEBUG] Forward pass complete. Output shape: torch.Size([16, 2])
# [DEBUG] Sample outputs: tensor([-2.0214,  1.7582], device='cuda:0', grad_fn=<SelectBackward0>)
# [DEBUG] Loss: 0.4796
# [DEBUG] Backward pass complete
# [DEBUG] Weights updated
# [DEBUG] Batch accuracy: 0.9375 (15/16)
# [DEBUG] Loaded file release_in_the_wild/30530.wav - Shape: torch.Size([1, 72048]), SR: 16000, Label: 1
# [DEBUG] Trimmed to 64000 samples - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 1
# [DEBUG] Loaded file release_in_the_wild/3975.wav - Shape: torch.Size([1, 68576]), SR: 16000, Label: 0
# [DEBUG] Trimmed to 64000 samples - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 0
# [INFO] Processing batch 471/1391
# [DEBUG] Batch waveform shape: torch.Size([16, 64000]), Label shape: torch.Size([16])
# [DEBUG] Data moved to cuda
# [DEBUG] Running forward pass...
# ...
# [DEBUG] Padded with 34384 zeros - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 0
# [DEBUG] Loaded file release_in_the_wild/22983.wav - Shape: torch.Size([1, 30113]), SR: 16000, Label: 0
# [DEBUG] Padded with 33887 zeros - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 0
# [INFO] Evaluating batch 291/298
# [DEBUG] Batch waveform shape: torch.Size([16, 64000])
# [DEBUG] Batch accuracy: 1.0000 (16/16)
# [DEBUG] Loaded file release_in_the_wild/27740.wav - Shape: torch.Size([1, 18737]), SR: 16000, Label: 0
# [DEBUG] Padded with 45263 zeros - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 0
# [RESULT] Evaluation complete. Accuracy: 0.9962 (4749/4767)
# [RESULT] Epoch 10/10, Loss: 0.0188, Train Accuracy: 0.9947, Dev Accuracy: 0.9962
# [INFO] Final evaluation on test set...
# [INFO] Starting evaluation on 298 batches
# [INFO] Model set to evaluation mode
# [DEBUG] Loaded file release_in_the_wild/18971.wav - Shape: torch.Size([1, 45201]), SR: 16000, Label: 0
# [DEBUG] Padded with 18799 zeros - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 0
# [INFO] Evaluating batch 1/298
# [DEBUG] Batch waveform shape: torch.Size([16, 64000])
# [DEBUG] Batch accuracy: 1.0000 (16/16)
# [DEBUG] Loaded file release_in_the_wild/159.wav - Shape: torch.Size([1, 72881]), SR: 16000, Label: 1
# [DEBUG] Trimmed to 64000 samples - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 1
# [INFO] Evaluating batch 11/298
# [DEBUG] Batch waveform shape: torch.Size([16, 64000])
# [DEBUG] Batch accuracy: 1.0000 (16/16)
# [DEBUG] Loaded file release_in_the_wild/10503.wav - Shape: torch.Size([1, 60464]), SR: 16000, Label: 0
# [DEBUG] Padded with 3536 zeros - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 0
# [DEBUG] Loaded file release_in_the_wild/1708.wav - Shape: torch.Size([1, 34033]), SR: 16000, Label: 1
# [DEBUG] Padded with 29967 zeros - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 1
# [INFO] Evaluating batch 21/298
# [DEBUG] Batch waveform shape: torch.Size([16, 64000])
# [DEBUG] Batch accuracy: 1.0000 (16/16)
# [DEBUG] Loaded file release_in_the_wild/30734.wav - Shape: torch.Size([1, 71168]), SR: 16000, Label: 0
# [DEBUG] Trimmed to 64000 samples - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 0
# [INFO] Evaluating batch 31/298
# [DEBUG] Batch waveform shape: torch.Size([16, 64000])
# [DEBUG] Batch accuracy: 1.0000 (16/16)
# [DEBUG] Loaded file release_in_the_wild/386.wav - Shape: torch.Size([1, 29169]), SR: 16000, Label: 0
# [DEBUG] Padded with 34831 zeros - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 0
# [DEBUG] Loaded file release_in_the_wild/4697.wav - Shape: torch.Size([1, 35552]), SR: 16000, Label: 0
# [DEBUG] Padded with 28448 zeros - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 0
# [INFO] Evaluating batch
298
# [DEBUG] Batch waveform shape: torch.Size([16, 64000])
# [DEBUG] Batch accuracy: 0.9375 (15/16)
# [DEBUG] Loaded file release_in_the_wild/4452.wav - Shape: torch.Size([1, 87152]), SR: 16000, Label: 0
# [DEBUG] Trimmed to 64000 samples - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 0
# [INFO] Evaluating batch 261/298
# [DEBUG] Batch waveform shape: torch.Size([16, 64000])
# [DEBUG] Batch accuracy: 1.0000 (16/16)
# [DEBUG] Loaded file release_in_the_wild/29509.wav - Shape: torch.Size([1, 69361]), SR: 16000, Label: 0
# [DEBUG] Trimmed to 64000 samples - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 0
# [DEBUG] Loaded file release_in_the_wild/23723.wav - Shape: torch.Size([1, 104177]), SR: 16000, Label: 1
# [DEBUG] Trimmed to 64000 samples - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 1
# [INFO] Evaluating batch 271/298
# [DEBUG] Batch waveform shape: torch.Size([16, 64000])
# [DEBUG] Batch accuracy: 1.0000 (16/16)
# [DEBUG] Loaded file release_in_the_wild/11835.wav - Shape: torch.Size([1, 52224]), SR: 16000, Label: 1
# [DEBUG] Padded with 11776 zeros - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 1
# [INFO] Evaluating batch 281/298
# [DEBUG] Batch waveform shape: torch.Size([16, 64000])
# [DEBUG] Batch accuracy: 1.0000 (16/16)
# [DEBUG] Loaded file release_in_the_wild/20147.wav - Shape: torch.Size([1, 54560]), SR: 16000, Label: 0
# [DEBUG] Padded with 9440 zeros - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 0
# [DEBUG] Loaded file release_in_the_wild/30818.wav - Shape: torch.Size([1, 153233]), SR: 16000, Label: 1
# [DEBUG] Trimmed to 64000 samples - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 1
# [INFO] Evaluating batch 291/298
# [DEBUG] Batch waveform shape: torch.Size([16, 64000])
# [DEBUG] Batch accuracy: 1.0000 (16/16)
# [DEBUG] Loaded file release_in_the_wild/8433.wav - Shape: torch.Size([1, 28096]), SR: 16000, Label: 0
# [DEBUG] Padded with 35904 zeros - New shape: torch.Size([1, 64000])
# [DEBUG] Final waveform shape: torch.Size([64000]), Label: 0
# [RESULT] Evaluation complete. Accuracy: 0.9956 (4746/4767)
# [RESULT] Final Test Accuracy: 0.9956
# [INFO] Script completed successfully

# %%
torch.save(model.state_dict(), "models/aasist_trained.pth")

# %%
# !pip install sounddevice
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting sounddevice
#   Downloading sounddevice-0.4.4-py3-none-any.whl (31 kB)
# Requirement already satisfied: CFFI>=1.0 in /home/202252321/.local/lib/python3.6/site-packages (from sounddevice) (1.15.1)
# Requirement already satisfied: pycparser in /home/202252321/.local/lib/python3.6/site-packages (from CFFI>=1.0->sounddevice) (2.21)
# Installing collected packages: sounddevice
# Successfully installed sounddevice-0.4.4

# %%
def preprocess_audio(file_path, target_sample_rate=16000, target_length=64000):
    try:
        waveform, sr = torchaudio.load(file_path)
        print(f"[DEBUG] Loaded file {file_path} - Shape: {waveform.shape}, SR: {sr}")

        # Resample if needed
        if sr != target_sample_rate:
            resampler = torchaudio.transforms.Resample(sr, target_sample_rate)
            waveform = resampler(waveform)
            print(f"[DEBUG] Resampled to {target_sample_rate}Hz")

        # Convert to mono if stereo
        if waveform.shape[0] > 1:
            waveform = torch.mean(waveform, dim=0, keepdim=True)
            print(f"[DEBUG] Converted to mono - New shape: {waveform.shape}")

        # Ensure correct length (4 seconds)
        if waveform.shape[1] > target_length:
            waveform = waveform[:, :target_length]  # Trim
        else:
            pad_size = target_length - waveform.shape[1]
            waveform = torch.nn.functional.pad(waveform, (0, pad_size))  # Pad

        print(f"[DEBUG] Final waveform shape: {waveform.shape}")
        return waveform.squeeze()
    
    except Exception as e:
        print(f"[ERROR] Failed to process audio {file_path}: {e}")
        return None

# %%
def infer(file_path):
    print(f"[INFO] Running inference on {file_path}")
    waveform = preprocess_audio(file_path)
    
    if waveform is None:
        return "Error in processing audio"

    waveform = waveform.to(device).unsqueeze(0)  # Add batch dimension
    
    with torch.no_grad():
        _, output = model(waveform)  # Forward pass
        prediction = torch.argmax(output, dim=1).item()

    label = "spoof" if prediction == 1 else "bona-fide"
    print(f"[RESULT] Predicted label: {label}")
    return label

# %%
# code for real-time testing
